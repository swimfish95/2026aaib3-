# %% [markdown]
# ![week02-1.png](data:image/png;base64,...)

# %% [markdown]
# ```cpp
# //week02-1cpp c++ string
# #include <iostream>///last week
# #include <string>///02 week
# //more word ver.
# int main()
# {
#     std::cout<<"what's your name?";
#     std::string name;//declare string name
#     std::cin>>name;//lastweek cin appearance
#     std::cout<<name<<"您好，今天教字串喔!";
# }
# ```

# %% [markdown]
# ![week02-2.png](data:image/png;base64,...)

# %% [markdown]
# ```cpp
# ///week02-2.cpp use namespace
# #include <iostream>///last week
# #include <string>///02 week
# using namespace std;/// use std [namespace]
# int main()
# {
#     cout<<"what's your name?";
#     string name;//declare string name
#     cin>>name;//lastweek cin appearance
#     cout<<name<<"您好，今天教命名空間喔!";
# }
# ```

# %% [markdown]
# ![week02-3.png](data:image/png;base64,...)

# %% [markdown]
# ```cpp
# //week02-3.cpp 第一題
# //leetcode 1768 merge strings
#
# class Solution {
# public:
#     string mergeAlternately(string word1, string word2) {
#         string ans;//put answer in string
#         int N1=word1.length(),N2=word2.length();
#         for(int i=0;i<max(N1,N2);i++){
#             if(i<N1)ans +=word1[i];//word1[i] put in ans
#             if(i<N2)ans +=word2[i];//word2[i] put in ans
#
#         }
#         return ans;//send answer
#     }
# };
# ```

# %% [markdown]
# ![week02-4.png](data:image/png;base64,...)

# %% [markdown]
# ```cpp
# //week02-4.cpp
# class Solution {
# public:
#     char findTheDifference(string s, string t) {
#         int U[26]={};//
#         for ( char c:s){//c++ for loop advanced writing
#             U[c-'a']++;// put letter in to corresponding garbage
#     }
#         for ( char c:t){
#             U[c-'a']--;
#             if(U[c-'a']<0)return c;//when no enough letter,find the murderer
#         }
#         return 0;
#     }
# };
# ```

# %% [markdown]
# ![week02-6.png](data:image/png;base64,...)

# %% [markdown]
# ```cpp
# #include <iostream>
# #include <string>
# #include <cctype>
# using namespace std;
#
# int main()
# {
#     string s;
#     cin >> s;
#     for (char c : s) {
#         if (isupper(c)) c = c - 'A' + 'a';
#         else if (islower(c)) c = c - 'a' + 'A';
#         cout << c;
#     }
#     cout << "\n";
# }
# ```
